# %% [markdown]
# Problem 1 is an exercise in statistics and probabilities using python.
#
# 1st thing: N pairs of random variables x and y from uniform pdf between 0 and 1
#
# 2nd interpreted as coordinates in the X,Y plane. Pairs will populate uniformly a square of area = 1.
#
# 3rd the number of n points that lie within the semicircle of radius 1 will vary from trial to trial, and will follow a binomial distribution (eq on sheet).
#
# f is the ratio of the area of the semicircle to that of the square: f = $\frac{1}{4}\pi$.
#
# Estimate: f as $\tilde{f} = \frac{n}{N}$ and compute $\pi$ as $\tilde{\pi} = 4\pi$

# %%
from math import sqrt
import numpy as np
import pandas as pd
from scipy.stats import uniform
import matplotlib.pyplot as plt

# %%
# Inititalizing N for factors of 10

N0 = 1
N1 = 1e1
N2 = 1e2
N3 = 1e3
N4 = 1e4
N5 = 1e5
N6 = 1e6

# %%
f_tilde = n/N1
pi_estimate = 4*f_tilde
sigma_f = sqrt((f_tilde*(1-f_tilde))/N)
rho = (pi_estimate-pi)/(sigma_f)

# %%
# Number n points that lie within the semicircle or 
# of radius r = 1. 
# 
#

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ## Exercise 3

# %%
## extract data:

df = pd.read_csv('CensusTownAndCityPopulation.csv')
dateData = df["7_2009"] #gives value columns
df
# Out:
#          State                     Town  7_2009
# 0      Alabama          .Abbeville city   2,930
# 1      Alabama         .Adamsville city   4,782
# 2      Alabama            .Addison town     709
# 3      Alabama              .Akron town     433
# 4      Alabama          .Alabaster city  29,861
# 5      Alabama        .Albertville city  20,115
# 6      Alabama     .Alexander City city  15,114
# 7      Alabama         .Aliceville city   2,417
# 8      Alabama            .Allgood town     737
# 9      Alabama            .Altoona town     966
# 10     Alabama          .Andalusia city   8,863
# 11     Alabama           .Anderson town     355
# 12     Alabama           .Anniston city  23,561
# 13     Alabama               .Arab city   8,272
# 14     Alabama            .Ardmore town   1,288
# 15     Alabama               .Argo town   1,961
# 16     Alabama             .Ariton town     746
# 17     Alabama              .Arley town     318
# 18     Alabama            .Ashford town   2,100
# ...

# %%
intMSDList = []
for ii in range(len(dateData)):
    strData = str(dateData[ii]) #single out one value from column and casts value to string
    strData = strData.replace(',','') #takes out commas
    strMSD = strData[0] #selects Most Significant Digit
    intMSD = int(strMSD) #casts string to integer
    intMSDList.append(intMSD) #populates list!

bins = 9
plt.hist(intMSDList, bins, color = 'r')
plt.title("Most significant digit recurrence")
plt.xlabel("Most Significant Integer Values")
plt.ylabel("Recurrence")
plt.show()

# %%
for ii in range(len(dataData_init)):

# %%
x = 2930
y = str(x)
print(y[0])
# Out:
# 2

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# ## Exercise 6
